# %%
import pandas as pd

# %%
matches = pd.read_csv("matches.csv", index_col=0)
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
#Dar uma olhada nas propriedades do DataFrame
matches.shape
# Out:
# (1389, 27)

# %%
#Quantas partidas temos de cada time?
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %% [markdown]
# ## Limpeza

# %%
#Verificar os tipos de dados 
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"]) #Converte a coluna date para datetime

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  match report  notes    sh   sot  dist   fk   pk  \
# ...

# %% [markdown]
# Criar modelos básicos de previsão
#
# #### Vamos criar a variavel "venue_code" que vai informar se uma equipa jogou em casa ou não.

# %%
matches["venue_code"]=matches["venue"].astype("category").cat.codes #Converte a coluna venue para categórica e depois para códigos  
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L  0.0
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L  0.0
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W  1.0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L  0.0
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  1.0
#
#      ga        opponent  ...  notes    sh   sot  dist   fk   pk pkatt season  \
# ...

# %% [markdown]
# Vamos criar a varivel opp_code para identificar cada equipa adversária por um nº especifíco

# %%
matches["opp_code"]= matches["opponent"].astype("category").cat.codes #Converte a coluna opponent para categórica e depois para códigos
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...    sh   sot  dist   fk   pk pkatt season  \
# 1       Tottenham  ...  18.0   4.0  16.9  1.0  0.0   0.0   2022
# 2    Norwich City  ...  16.0   4.0  17.3  1.0  0.0   0.0   2022
# 3         Arsenal  ...  25.0  10.0  14.3  0.0  0.0   0.0   2022
# 4  Leicester City  ...  25.0   8.0  14.0  0.0  0.0   0.0   2022
# 6     Southampton  ...  16.0   1.0  15.7  1.0  0.0   0.0   2022
#
#               team  venue_code  opp_code
# 1  Manchester City           0        18
# ...

# %% [markdown]
# Vamos criar uma variavel que pega apenas a hora da varivel time

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype(int) #Extrai a hora da coluna time e converte para inteiro
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   sot  dist   fk   pk pkatt season             team  \
# 1       Tottenham  ...   4.0  16.9  1.0  0.0   0.0   2022  Manchester City
# 2    Norwich City  ...   4.0  17.3  1.0  0.0   0.0   2022  Manchester City
# 3         Arsenal  ...  10.0  14.3  0.0  0.0   0.0   2022  Manchester City
# 4  Leicester City  ...   8.0  14.0  0.0  0.0   0.0   2022  Manchester City
# 6     Southampton  ...   1.0  15.7  1.0  0.0   0.0   2022  Manchester City
#
#   venue_code  opp_code  hour
# ...

# %% [markdown]
# Vamos criar uma coluna que defina por nº os dias da semana: Segunda=0; Terça=1; Quarta=2;Quinta=3;Sexta=4; Sábado=5; Domingo=6.

# %%
matches["day_code"] = matches["date"].dt.dayofweek #Extrai o dia da semana da coluna date   
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  dist   fk   pk  pkatt season             team  \
# 1       Tottenham  ...  16.9  1.0  0.0    0.0   2022  Manchester City
# 2    Norwich City  ...  17.3  1.0  0.0    0.0   2022  Manchester City
# 3         Arsenal  ...  14.3  0.0  0.0    0.0   2022  Manchester City
# 4  Leicester City  ...  14.0  0.0  0.0    0.0   2022  Manchester City
# 6     Southampton  ...  15.7  1.0  0.0    0.0   2022  Manchester City
#
#   venue_code opp_code  hour  day_code
# 1          0       18    16         6
# ...

# %%
matches["target"] = (matches["result"]=="w").astype("int") #Cria uma coluna target com valores booleanos
matches.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  target
# ...

# %% [markdown]
# ## Criar o primeiro modelo de IA

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
#Treino
train = matches[matches["date"]<"2022-01-01"]

#Teste
test = matches[matches["date"]>"2022-01-01"]

# %%
#Criar a previsão
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"]) #Treina o modelo
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds=rf.predict(test[predictors]) #Faz a previsão

# %%
from sklearn.metrics import accuracy_score

acc=accuracy_score(test["target"], preds) #Calcula a acurácia

# %%
acc
# Out:
# 1.0

# %% [markdown]
# Combinar os valores actuais e os previstos

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))   #Cria um DataFrame com os valores reais e previstos

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"]) #Cria uma matriz de confusão
# Out:
# predicted    0
# actual
# 0          276

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds) #Calcula a precisão
# Out:
# c:\Users\Elvis\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.0

# %% [markdown]
# Adicionar a perfomance de cada equipa

# %%
grouped_matches= matches.groupby("team") #Agrupa as partidas por time

# %%
group=grouped_matches.get_group("Manchester City") #Pega as partidas do Manchester City

group.head()
# Out:
#         date   time            comp        round  day venue result   gf   ga  \
# 1 2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2 2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3 2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4 2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6 2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...   fk   pk  pkatt  season             team venue_code  \
# 1       Tottenham  ...  1.0  0.0    0.0    2022  Manchester City          0
# 2    Norwich City  ...  1.0  0.0    0.0    2022  Manchester City          1
# 3         Arsenal  ...  0.0  0.0    0.0    2022  Manchester City          1
# 4  Leicester City  ...  0.0  0.0    0.0    2022  Manchester City          0
# 6     Southampton  ...  1.0  0.0    0.0    2022  Manchester City          1
#
#   opp_code hour  day_code  target
# ...

# %%
def rolling_avarages (group, cols, new_cols): #Função que calcula a média móvel
    group = group.sort_values("date") #Ordena as partidas por data, crescente
    rolling_states = group[cols].rolling(3, closed="left").mean() #Calcula a média móvel sobre as 3 últimas partidas 
    group[new_cols] = rolling_states #Cria uma nova coluna com a média móvel
    group = group.dropna(subset=new_cols) #Remove os valores nulos
    return group

# %% [markdown]
# dropna(subset=new_cols): Isso faz com que o DataFrame remova linhas que tenham valores NaN especificamente na(s) coluna(s) new_col (a nova coluna criada com as médias móveis). Ou seja, qualquer linha que não tenha uma média móvel calculada (por exemplo, as primeiras linhas da série, que não têm três partidas anteriores para calcular a média) será removida.

# %% [markdown]
# gf= golos feitos <br>
# ga=golos sofridos<br>
# sh= chutes feitos<br>
# sot=chutes no alvo<br>
# dist= chutes feitos a distãncia<br>
# fk=Livres<br>
# pk=pensaltes<br>
# pkatt=tentativas de penaltes

# %%
cols = ["gf","ga","sh","dist","fk","pk","pkatt"] #Colunas que serão usadas para calcular a média móvel

# %%
new_cols = [f"{c}_rolling" for c in cols] #Cria uma lista com os nomes das novas colunas
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_avarages(group, cols, new_cols) #Calcula a média móvel
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  hour  day_code  target  gf_rolling ga_rolling  \
# ...
